# %%
from genesis_read import *

# %%
filePath = '/home/libb/gitlab_proj/s2e_fel/bbl_test/time_20211025_onlyLwake/genesis_simu/test/rad.out'

# %%
start = time.time()
out1 = read_out_file(filePath, read_level=2, precision=float)
end = time.time()
print(end-start)
# Out:
# 0.0789341926574707

# %%
plt.figure()

plt.plot(out1.I)

# %%
plt.figure()

plt.axes(yscale ='log')
plt.plot(out1.z,out1.power_z_mean)

plt.show()

# %%
plt.figure()

plt.axes(yscale ='log')
plt.plot(out1.z[0:1310],out1.pulse_energy[0:1310]*1e6)

plt.show()

# %%
out1.z[1319]
# Out:
# 24.494

# %%
out1.pulse_energy[1319]*1e6
# Out:
# 240.8006477780621

# %%
plt.figure()
plt.plot(out1.t,out1.power_int)
plt.show()

# %%
 out1.calc_spec(mode='ff',npad=1)

# %%
plt.figure()
plt.plot(out1.freq_lamd,out1.spec[:,-1])

plt.xlim(0.795, 0.815)

plt.show()

# %%
dir(out1)
# Out:
# ['E',
#  'I',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'angle',
#  'aw',
#  'beam_charge',
#  'bunching',
#  'calc_radsize',
#  'calc_spec',
#  'dt',
#  'el_energy',
#  'energy',
#  'error',
#  'fileName',
#  'filePath',
#  'freq_ev',
#  'freq_ev_mean',
#  'freq_lamd',
#  'increment',
#  'leng',
#  'max_power',
#  'n',
#  'nSlices',
#  'nZ',
#  'n_photons',
#  'ncar',
#  'p_int',
#  'p_mid',
#  'parameters',
#  'phase_fix',
#  'phi',
#  'phi_mid',
#  'power',
#  'power_int',
#  'power_z_max',
#  'power_z_mean',
#  'pulse_energy',
#  'qfld',
#  'r_size',
#  're_read',
#  's',
#  'sliceKeys',
#  'sliceKeys_used',
#  'sliceValues',
#  'sn_Imax',
#  'spec',
#  'spec_mode',
#  'spec_phot_density',
#  't',
#  'wig',
#  'xrms',
#  'yrms',
#  'z',
#  'zSlice']
